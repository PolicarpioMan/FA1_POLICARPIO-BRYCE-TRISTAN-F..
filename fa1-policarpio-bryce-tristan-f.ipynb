# %% [markdown]
# # **Start the Pyhton interpreter and use it as a calculator**

# %% [markdown]
# **2. How many miles are there in 10km? Hint: There are 1.61km in a mile.**

# %%
km=10
mile_per_km=1.61
miles=km/mile_per_km
print('%.2f kilometers is equal to %.2f miles'%(km,miles))
# Out:
# 10.00 kilometers is equal to 6.21 miles

# %% [markdown]
# **3. If you run a 10km in 42 minutes 42 seconds, what is your average pace (time per mile, per minute and seconds)? What is you average speed in miles per hour?******

# %%
#Minutes in the question
min=42
#seconds in your race
secs=42
#total time in your race
time=42+(secs/60)
km=10
mile=km/1.61
pace=time/mile
mph=mile/(time/60)
print('If you ran %.2f km in %.2f minutes and seconds, Your average speed in terms of %.2f miles is %.2f mph'%(km,time,mile,mph) )
# Out:
# If you ran 10.00 km in 42.70 minutes and seconds, Your average speed in terms of 6.21 miles is 8.73 mph
